# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinGalvao/DataScience/blob/main/Entregable_III_Martin_Galvao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduccion 📚

# %% [markdown]
# En este proyecto, se creo una red neuronal la cual nos permite realizar una prediccion sobre la valoracion de las peliculas.

# %% [markdown]
# ## Imports

# %% [markdown]
# Se realizaron los imports correspondientes

# %%
import pandas as pd
from nltk.corpus import stopwords
import nltk
import pandas as pd
from nltk.corpus import stopwords
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MartinGalvao/DataScience/8a69ab848c032e06d095c01473cc2933f0b54a61/Top%201000%20IMDB%20movies%20(1).csv')

# %% [markdown]
# ## Visualizacion DF

# %%
df.head()
# Out:
#    Unnamed: 0                                     Movie Name Year of Release  \
# 0           0                       The Shawshank Redemption          (1994)
# 1           1                                  The Godfather          (1972)
# 2           2                                The Dark Knight          (2008)
# 3           3  The Lord of the Rings: The Return of the King          (2003)
# 4           4                               Schindler's List          (1993)
#
#   Watch Time  Movie Rating Meatscore of movie   Votes     Gross  \
# 0    142 min           9.3         81          34,709   $28.34M
# 1    175 min           9.2        100          34,709  $134.97M
# 2    152 min           9.0         84          34,709  $534.86M
# 3    201 min           9.0         94          34,709  $377.85M
# 4    195 min           9.0         94          34,709   $96.90M
#
#                                          Description
# 0  Two imprisoned men bond over a number of years...
# ...

# %% [markdown]
# # NPL ⚙

# %% [markdown]
# Se realizaron tareas de preprocesamiento NPL

# %%
import pandas as pd



# 1. Tokenization: Splitting text into individual words or tokens.
df['Tokens'] = df['Movie Name'].str.lower().str.split()

# 2. Removing Stop Words: Removing common words that don't carry much meaning (e.g., "the," "a," "is").
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
df['Filtered_Tokens'] = df['Tokens'].apply(lambda tokens: [token for token in tokens if token not in stop_words])

df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    Unnamed: 0                                     Movie Name Year of Release  \
# 0           0                       The Shawshank Redemption          (1994)
# 1           1                                  The Godfather          (1972)
# 2           2                                The Dark Knight          (2008)
# 3           3  The Lord of the Rings: The Return of the King          (2003)
# 4           4                               Schindler's List          (1993)
#
#   Watch Time  Movie Rating Meatscore of movie   Votes     Gross  \
# 0    142 min           9.3         81          34,709   $28.34M
# 1    175 min           9.2        100          34,709  $134.97M
# 2    152 min           9.0         84          34,709  $534.86M
# 3    201 min           9.0         94          34,709  $377.85M
# ...

# %%
import pandas as pd
from nltk.corpus import stopwords
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

df = pd.read_csv('https://raw.githubusercontent.com/MartinGalvao/DataScience/8a69ab848c032e06d095c01473cc2933f0b54a61/Top%201000%20IMDB%20movies%20(1).csv')



# 1. Tokenization: Splitting text into individual words or tokens.
df['Tokens'] = df['Movie Name'].str.lower().str.split()

# 2. Removing Stop Words: Removing common words that don't carry much meaning (e.g., "the," "a," "is").
stop_words = set(stopwords.words('english'))
df['Filtered_Tokens'] = df['Tokens'].apply(lambda tokens: [token for token in tokens if token not in stop_words])

# 3. Stemming: Reducing words to their root form (e.g., "running" to "run").
stemmer = PorterStemmer()
df['Stemmed_Tokens'] = df['Filtered_Tokens'].apply(lambda tokens: [stemmer.stem(token) for token in tokens])

# 4. Lemmatization: Reducing words to their dictionary form (e.g., "better" to "good").
lemmatizer = WordNetLemmatizer()
df['Lemmatized_Tokens'] = df['Filtered_Tokens'].apply(lambda tokens: [lemmatizer.lemmatize(token) for token in tokens])



df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    Unnamed: 0                                     Movie Name Year of Release  \
# 0           0                       The Shawshank Redemption          (1994)
# 1           1                                  The Godfather          (1972)
# 2           2                                The Dark Knight          (2008)
# 3           3  The Lord of the Rings: The Return of the King          (2003)
# 4           4                               Schindler's List          (1993)
#
#   Watch Time  Movie Rating Meatscore of movie   Votes     Gross  \
# 0    142 min           9.3         81          34,709   $28.34M
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')


# 1. Data Preparation
df = pd.read_csv('https://raw.githubusercontent.com/MartinGalvao/DataScience/8a69ab848c032e06d095c01473cc2933f0b54a61/Top%201000%20IMDB%20movies%20(1).csv')


stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    tokens = nltk.word_tokenize(text.lower())
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalnum() and token not in stop_words]
    return " ".join(tokens)

df['Processed_Title'] = df['Movie Name'].apply(preprocess_text)

# 2. Tokenization and Padding
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['Processed_Title'])
sequences = tokenizer.texts_to_sequences(df['Processed_Title'])
max_length = max([len(seq) for seq in sequences])
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# 3. Split Data
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences, df['Movie Rating'], test_size=0.2, random_state=42)

# 4. Build the Neural Network
model = Sequential()
model.add(Embedding(5000, 128, input_length=max_length))
model.add(LSTM(128))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# 5. Train the Model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# 6. Evaluate the Model
loss, mae = model.evaluate(X_test, y_test)
print("Error absoluto medio:", mae)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 40.1036 - mae: 5.8218 - val_loss: 0.4419 - val_mae: 0.4239
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.5858 - mae: 0.5896 - val_loss: 0.3596 - val_mae: 0.4805
# Epoch 3/10
# ...

# %% [markdown]
# # Red Neuronal 🧠

# %% [markdown]
# Se creo la Red Neuronal la cual permite predecir la valoracion.

# %%
# 7. Make Predictions with User Input
def predict_rating(movie_title):
  processed_title = preprocess_text(movie_title)
  sequence = tokenizer.texts_to_sequences([processed_title])
  padded_sequence = pad_sequences(sequence, maxlen=max_length, padding='post')
  prediction = model.predict(padded_sequence)[0][0]
  return prediction

# Get user input
user_movie = input("Ingrese el titulo de la pelicula ")

# Predict the rating
predicted_rating = predict_rating(user_movie)

print(f"Calificación prevista para '{user_movie}': {predicted_rating:.2f}")

# %% [markdown]
# # Mejoras a la Red Neuronal 🛠

# %% [markdown]
# Se le agregaron capas y se mejoro la red.

# %%
model = Sequential()
model.add(Embedding(5000, 128, input_length=max_length))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# 5. Train the Model
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test, y_test))


# 6. Evaluate the Model
loss, mae = model.evaluate(X_test, y_test)
print("Error absoluto medio:", mae)

# %%
# 4. Build the Neural Network
model = Sequential()
model.add(Embedding(5000, 128, input_length=max_length))
model.add(LSTM(128, return_sequences=True))
model.add(LSTM(64))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# 5. Train the Model
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test, y_test))
# Increase epochs and batch size

# 6. Evaluate the Model
loss, mae = model.evaluate(X_test, y_test)
print("Error absoluto medio:", mae)

model.summary()

# %% [markdown]
# # Red Neuronal Mejorada 🧠🧰

# %% [markdown]
# Luego de agregarle capas y mejorar, podemos ver que nuestra Red mejoro y sera más efectiva a la hora de realizar la prediccion.

# %%
# 7. Make Predictions with User Input
def predict_rating(movie_title):
  processed_title = preprocess_text(movie_title)
  sequence = tokenizer.texts_to_sequences([processed_title])
  padded_sequence = pad_sequences(sequence, maxlen=max_length, padding='post')
  prediction = model.predict(padded_sequence)[0][0]
  return prediction

# Get user input
user_movie = input("Ingrese el titulo de la pelicula: ")

# Predict the rating
predicted_rating = predict_rating(user_movie)

print(f"Calificación prevista para '{user_movie}': {predicted_rating:.2f}")

# %% [markdown]
# # Conclusion

# %% [markdown]
# Se llego a la conclusion que mediante la agregacion de capas a nuestra Red esta mejoro y expresa un mejor rendimiento.
